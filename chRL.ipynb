# %% [markdown]
# # comparison of genai courses:
#
# ![Screenshot 2025-08-23 192126.png](<attachment:Screenshot 2025-08-23 192126.png>)  ![Screenshot 2025-08-23 195837.png](<attachment:Screenshot 2025-08-23 195837.png>)  ![Screenshot 2025-08-23 195534.png](<attachment:Screenshot 2025-08-23 195534.png>) ![Screenshot 2025-08-23 195626.png](<attachment:Screenshot 2025-08-23 195626.png>) ![Screenshot 2025-08-23 195640.png](<attachment:Screenshot 2025-08-23 195640.png>)

# %%
import  gymnasium as gym 
env = gym.make("CartPole-v1")
obs = env.reset()
obs
# Out:
# (array([-0.01584202, -0.04291078, -0.00757102, -0.0123486 ], dtype=float32),
#  {})

# %%
env.render()
# Out:
# a:\all_softwares\python_setup\py3.12\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:250: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(

# %%
img = env.render()
env.action_space
# Out:
# a:\all_softwares\python_setup\py3.12\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:250: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Discrete(2)

# %%
action = 1 
obs, reward, done, info = env.step(action)
print(obs)
print(reward)
print(done)
print(info)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 action = 1
# ----> 2 obs, reward, done, info = env.step(action)
#       3 print(obs)
#       4 print(reward)
#
# ValueError: too many values to unpack (expected 4)

# %%
def basic_policy(obs):
    angle = obs[2]
    return 0 if angle < 0 else 1
totals = []
for episode in range(500):
    episode_rewards = 0
    obs = env.reset()
    for step in range(200):
        action = basic_policy(obs)
    obs, reward, done, info = env.step(action)
    episode_rewards += reward
    if done:
        break
totals.append(episode_rewards)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 9
#       7 obs = env.reset()
#       8 for step in range(200):
# ----> 9     action = basic_policy(obs)
#      10 obs, reward, done, info = env.step(action)
#      11 episode_rewards += reward
#
# Cell In[14], line 2, in basic_policy(obs)
#       1 def basic_policy(obs):
# ----> 2     angle = obs[2]
#       3     return 0 if angle < 0 else 1
#
# IndexError: tuple index out of range
